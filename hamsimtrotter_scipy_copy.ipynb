# %%
from hamsimtrotter_scipy import AlgorithmHamSimTrotterCheat
from pytket.pauli import Pauli, QubitPauliString
from pytket.utils import QubitPauliOperator
from pytket.circuit import Circuit,Qubit

# %% [markdown]
# ## Initial State

# %%
initial_state_circ = Circuit(4)
initial_state_circ.X(0)
initial_state_circ.X(1)
# Out:
# [X q[0]; X q[1]; ]

# %% [markdown]
# ## Hamiltonian
# - This is a random one I found

# %%
hamiltonian = QubitPauliOperator(
    {
        QubitPauliString([Qubit(0)], [Pauli.Z]): 0.1,
        QubitPauliString(
            [Qubit(0), Qubit(1), Qubit(2), Qubit(3)],
            [Pauli.Y, Pauli.Z, Pauli.X, Pauli.X],
        ): 0.4,
        QubitPauliString([Qubit(0), Qubit(1)], [Pauli.X, Pauli.X]): 0.2,
    }
)

# %% [markdown]
# ## Measurements
# - The operators to measure after each trotter step.
# - Here just tracking the <Z> measurements of each qubits

# %%
measurements = [QubitPauliOperator({QubitPauliString([Qubit(i)], [Pauli.Z]): 1}) for i in range(initial_state_circ.n_qubits)]

# %%
t_max=20
n_trotter_steps = 1000

# %%
trotter_time_evolution = AlgorithmHamSimTrotterCheat(initial_state_circ,hamiltonian,measurements,t_max,n_trotter_steps)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_21485/2448326325.py in <module>
# ----> 1 trotter_time_evolution = AlgorithmHamSimTrotterCheat(initial_state_circ,hamiltonian,measurements,t_max,n_trotter_steps)
#
# ~/tket_coding/example_code/trotter/hamsimtrotter_scipy.py in __init__(self, initial_state, qubit_operator, measurements, t_max, n_trotter_steps, *args, **kwargs)
#      30         self._time_space = numpy.linspace(0,t_max,n_trotter_steps)
#      31
# ---> 32         self._initial_state = AerStateBackend().get_state(initial_state)
#      33         self._measurements = [m.to_sparse_matrix(self._n_qubits) for m in measurements]
#      34         self._trotter_step = expm(-1j * qubit_operator.to_sparse_matrix(self._n_qubits) * self._time_step ) #exp(-i H tau)
#
# AttributeError: 'AerStateBackend' object has no attribute 'get_state'

# %%
trotter_time_evolution.execute()

# %% [markdown]
# ## Dataframe
# - returns a pandas dataframe which has easy plotting and saving of data

# %%
trotter_time_evolution.evolved_measuremets.plot()
# Out:
# <AxesSubplot:xlabel='Time'>
